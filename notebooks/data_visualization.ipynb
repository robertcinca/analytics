# %%
catalog.list()
# Out:
# [
#     'application_record',
#     'credit_record',
#     'merged_record',
#     'model',
#     'metrics',
#     'parameters',
#     'params:train_fraction',
#     'params:random_state',
#     'params:target_column',
#     'params:n_estimators',
#     'params:max_features',
#     'params:max_depth',
#     'params:min_samples_split',
#     'params:min_samples_leaf'
# ]

# %%
catalog.load("merged_record")
# Out:
# [02/01/23 00:49:28] INFO     Loading data from 'merged_record' (ParquetDataSet)...              ]8;id=325836;file:///Users/robertcinca/.local/share/virtualenvs/template-analytics-x4ftvWbN/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=615756;file:///Users/robertcinca/.local/share/virtualenvs/template-analytics-x4ftvWbN/lib/python3.9/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>CODE_GENDER</th>
#       <th>FLAG_OWN_CAR</th>
#       <th>FLAG_OWN_REALTY</th>
#       <th>CNT_CHILDREN</th>
#       <th>AMT_INCOME_TOTAL</th>
#       <th>NAME_INCOME_TYPE</th>
# ...
